# %%
# import libraries

import csv
import pandas as pd

# %%
# source 1: kaggale.com

url_1 = "rating_sale_info.csv"

kaggle_data = pd.read_csv(url_1)

kaggle_data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
# source 2: scraping whatoplay: "https://whatoplay.com/best?sort-by=gamer_score"

url_2 = "scraping_result.csv"

whatoplay_data = pd.read_csv(url_2)

whatoplay_data
# Out:
#                                            Name  Platform  Play Score  \
# 0                            Grand Theft Auto V  Xbox 360        9.64
# 1      Naruto Shippuden: Ultimate Ninja Storm 3  Xbox 360        8.68
# 2                                  A Short Hike        PC        8.98
# 3                             Final Fantasy VII       PS4        8.87
# 4                                  The Room Two   Android        9.23
# ...                                         ...       ...         ...
# 11355         Warhammer 40,000: Dawn of War III        PC        6.30
# 11356                                  Splendor       iOS        6.43
# 11357                                   FIFA 18        PC        6.29
# 11358                                  NBA 2K19        PC        6.07
# 11359                                  NBA 2K18  Xbox One        6.03
#
#        Game Score  Critic Score
# 0            9.97          9.30
# 1            9.91          7.45
# ...

# %%
total_data = pd.merge(kaggle_data, whatoplay_data, how = "left", on=["Name", "Platform"] )

total_data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
# Store the final table as csv file

total_data.to_csv("data/csv/master_table.csv", index= False, header = True)

# %%
# convert csv to jason format

total_data.to_json ("data/json/master_table.json")
kaggle_data.to_json ("data/json/kaggle_data.json")
whatoplay_data.to_json ("data/json/whatoplay_data.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-5503e23bba9e> in <module>
#       1 # convert csv to jason format
#       2
# ----> 3 total_data.to_json ("data/json/master_table.json", index= False)
#       4 kaggle_data.to_json ("data/json/kaggle_data.json", index= False)
#       5 whatoplay_data.to_json ("data/json/whatoplay_data.json", index= False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#    2362             compression=compression,
#    2363             index=index,
# -> 2364             indent=indent,
#    2365         )
#    2366
#
# ...
