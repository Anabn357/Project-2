# %%
# import libraries

import csv
import pandas as pd

# %%
# source 1, only sales data based on platform, genre, and publisher

url_1 = "data/csv/sales_data.csv"
sales_data = pd.read_csv(url_1)
sales_data = sales_data.dropna()
sales_data.to_csv("data/csv/sales_data_clean.csv", index= False, header = True)

sales_data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# source : sales data+ rating and critic scores:

url_2 = "data/csv/rating_sale.csv"
rating_sale = pd.read_csv(url_2)
rating_sale = rating_sale.dropna()
rating_sale.to_csv("data/csv/rating_sale_clean.csv", index= False, header = True)
rating_sale
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii           2006.0    Sports
# 2                         Mario Kart Wii      Wii           2008.0    Racing
# 3                      Wii Sports Resort      Wii           2009.0    Sports
# 6                  New Super Mario Bros.       DS           2006.0  Platform
# 7                               Wii Play      Wii           2006.0      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
# source 3: scraping whatoplay: "https://whatoplay.com/best?sort-by=gamer_score" => game score, play score, critic score

url_3 = "data/csv/scraping_result.csv"

whatoplay_data = pd.read_csv(url_3)

whatoplay_data = whatoplay_data.dropna()
whatoplay_data.to_csv("data/csv/whatoplay_data_clean.csv")

whatoplay_data
# Out:
#                                            Name  Platform  Play Score  \
# 0                            Grand Theft Auto V  Xbox 360        9.64
# 1      Naruto Shippuden: Ultimate Ninja Storm 3  Xbox 360        8.68
# 2                                  A Short Hike        PC        8.98
# 3                             Final Fantasy VII       PS4        8.87
# 4                                  The Room Two   Android        9.23
# ...                                         ...       ...         ...
# 11355         Warhammer 40,000: Dawn of War III        PC        6.30
# 11356                                  Splendor       iOS        6.43
# 11357                                   FIFA 18        PC        6.29
# 11358                                  NBA 2K19        PC        6.07
# 11359                                  NBA 2K18  Xbox One        6.03
#
#        Game Score  Critic Score
# 0            9.97          9.30
# 1            9.91          7.45
# ...

# %%
total_data = pd.merge(rating_sale, whatoplay_data, how = "inner", on=["Name", "Platform"] )

total_data
# Out:
#                                    Name Platform  Year_of_Release      Genre  \
# 0                    Grand Theft Auto V      PS3           2013.0     Action
# 1            Call of Duty: Black Ops II      PS3           2012.0    Shooter
# 2        Call of Duty: Modern Warfare 3      PS3           2011.0    Shooter
# 3                          Mario Kart 7      3DS           2011.0     Racing
# 4               Call of Duty: Black Ops      PS3           2010.0    Shooter
# ...                                 ...      ...              ...        ...
# 1190                  Alone in the Dark       PC           2008.0  Adventure
# 1191             Clive Barker's Jericho       PC           2007.0    Shooter
# 1192    Transformers: Fall of Cybertron       PC           2012.0     Action
# 1193                              Trine       PC           2009.0     Action
# 1194  Metal Gear Solid V: Ground Zeroes       PC           2014.0     Action
#
# ...

# %%
# Store the final table as csv file

total_data.to_csv("data/csv/master_table_clean.csv", index= False, header = True)

# %%
# convert csv to jason format

total_data.to_json ("data/json/master_table.json")
rating_sale.to_json ("data/json/rating_sale.json")
sales_data.to_json("data/json/sales_data.json")
whatoplay_data.to_json ("data/json/whatoplay_data.json")
